# %% [markdown]
# ### Implements the method of characteristics to solve a one-dimensional hyperbolic equation that describe the transient surge pressure.  This method is a first order approximation.

# %%
import numpy as np
from pint import UnitRegistry
import math
ureg = UnitRegistry()
np.set_printoptions(precision=6)
import sys
sys.path.append('/Users/Lampe/PyScripts/surgeAnalysis')
import SurgeFunc as sf
import pdb

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### Problem Data

# %%
# numerical parameters
nel = int(800) # number of elements
tf = 15.0 # total calculation tim (sec)

#problem Data
Tc = 10. # time for total valve closure (sec)
degTheta = 90.0 # 90->vertical well, 0->horizontal well
p0 = 20 # reservoir pressure (MPa)
q0 = 0.2*3600 # SS flow rate (m3/hr)

#casing data
rough = 0.9 # roughness (mm)
d = 273.1 # mm -> inner diameter
L = 100. # length of conduit (m)

#fluid specific data
mu = np.array([1.60 * 10**-3]) # Dynamic viscosity (Pa-s, N-s/m2)
sg = np.array([1.0]) # specific gravity
a = np.array([1000.]) # speed of sound in fluid (m/s)

# %% [markdown]
# ### Check Fluid Velocity

# %%
area = np.pi * (d/1000)**2 / 4. #m 2
velocity = q0 / area / 3600.
print(velocity) # m/sec
# Out:
# 3.41426097432

# %% [markdown]
# ### Calculated Constants

# %%
nnode = nel + 1 # number of nodes
x = np.linspace(0., L, nnode) # spatial discretization
nrlp = np.sum(x[:]>=L)# number of reachs in last segment

dx = L/nel
s = dx/max(a) # time step size (s)
t = np.linspace(0, tf, tf/s + 1) # time discretization

# %% [markdown]
# ### Courant Evaluation

# %%
Courant = max(a)*s/dx; Courant
print(Courant)
print(s)
print(dx)
print(a[0]*s)
# Out:
# 1.0
# 0.000125
# 0.125
# 0.125

# %% [markdown]
# ### Fluid / Conduit specific values

# %%
A = np.pi * (d / 1000.)**2 / 4. # area of flow (m2)
ani = L / (s*a)
g = 9.806 # m/s2
rho = sg * 1000 # kg/m3

f = 0.
cf = 0.
ca = np.zeros(len(a))
cb = 0.
for i in xrange(len(a)):
    f = sf.SS_DeltaH(q0, mu[i], sg[i], d, rough, x, degTheta, units=1).Calc().f # friction factor 
    ca[i] = g * A / a[i] # m2/sec
    cf = s * f/(2*(d/1000.)*A) #assumed constant (sec/m3)
    cb = s * g * A * np.sin(degTheta*np.pi / 180.0)

# %%
print(f) #friction factor
print(cf)
# Out:
# 0.0270924699661
# 0.000105845801564

# %% [markdown]
# ### Create idx Array - Determines where changes in system occur (e.g., conduit diameter, fluid, etc.)

# %%
idx = np.zeros(len(x)).astype(int) # array of integers
chng = np.arange(0,len(a),1) # each index of the 'chng' array indicates a change in fluid type
for i in xrange(len(idx)):
    idx[i] = chng[0]

# %% [markdown]
# ### Steady State Calc

# %%
h0_arr = np.zeros(len(x)) # head (m)
q0_arr = np.zeros(len(x)) # flow rate (m3/hr)
p0_arr = np.zeros(len(x)) # pressure (MPa)
    
for i in xrange(len(x)):
    q0_arr[i] = q0 / 3600. # steady flow (m3/sec)
    h0_arr[i] = (p0*10**6)/(rho[idx[i]]*g) + sf.SS_DeltaH(q0, mu[idx[i]], sg[idx[i]], d, rough,
                                                  x[i], degTheta, units=1).Calc().dh # head (m)
    p0_arr[i] = p0+sf.SS_DeltaH(q0,mu[idx[i]],sg[idx[i]],d,rough,x[i],degTheta,units=1).Calc().dp

# %%
fig_ICs, ax = plt.subplots(figsize = (12,8))
   
# ax.plot(h[:,start:stop:inc],x)
ax.plot(p0_arr,x, label='Initial Conditions')
# ax.legend(lbl, frameon=1, framealpha = 1, loc=2)

# ax.invert_yaxis()
# ax.invert_xaxis()
ax.set_xlabel('Pressure (MPa)', fontsize = 12)
ax.set_ylabel('Length (m)', fontsize = 12)
# ax.set_title(''r'Time Integration Convergence Analysis, $\alpha = 0.5 \Rightarrow$ Implicit' , fontsize = 16)
ax.grid(b = True, which = 'major')
ax.grid(b = True, which = 'major')
# ax.set_ylim(0, 2)

# fig_name = 'InitialConditions.pdf'
# path = '/Users/Lampe/Documents/PB/SurgeAnalysis/Results/'
# fig_ICs.savefig(path + fig_name)

# %% [markdown]
# ### Valve Control

# %%
y = np.array([ 1.    ,  0.998 ,  0.9928,  0.9845,  0.9734,  0.9599, 0.9441,
        0.9263,  0.9068,  0.8859,  0.8638,  0.8406,  0.8166,  0.7921,
        0.7671,  0.7419,  0.7167,  0.6917,  0.667 ,  0.6426,  0.6185,
        0.5946,  0.5708,  0.5471,  0.5235,  0.5   ,  0.4765,  0.4529,
        0.4292,  0.4054,  0.3815,  0.3574,  0.333 ,  0.3083,  0.2833,
        0.2581,  0.2329,  0.2079,  0.1834,  0.1594,  0.1362,  0.1141,
        0.0932,  0.0737,  0.0559,  0.0401,  0.0266,  0.0155,  0.0072,
        0.002 ,  0.]) # fraction open over value closure time
tc = np.linspace(0,Tc, len(y)) # characteristic times associated with 'y'

# %% [markdown]
# ### Main Program

# %% [markdown]
# Compile main loop in C using Numba's Just In Time compiler (JIT)

# %%
# from numba import jit

# %% [markdown]
# build arrays outside of the main function

# %%
# rows-> spatial disc; column -> temporal disc
rho = 0.
area = 0.
v = 0.
Re = 0.
    
row = x.size
col = t.size
qp = np.empty(row, dtype = np.float) # future flow rate along the positive characteristic (m3/hr)
hp = np.empty(row, dtype = np.float) # future head along the positive characteristic (m3/hr)

hin = np.empty((row, col), dtype = np.float) # head (m)
qin = np.empty((row, col), dtype = np.float) # flow rate (m3/hr)
pin = np.empty((row, col), dtype = np.float) # pressure (MPa)

# %%
# @jit
# def MethodChar01(x, t, q0_arr, h0_arr, p0_arr, ca, cf, cb, idx, sg, ID, mu, rough,s, 
#          row, col, qp, hp, h, q, p,rho,area,v,Re,f):
#     ID = ID/1000. # convert from mm to m
#     rough = rough/1000. #convert form mm to m
#     area = np.pi * ID **2 / 4.# m2
    
#     # define initial conditions
#     for i in range(row):
#         q[i,0] = q0_arr[i]
#         h[i,0] = h0_arr[i]
#         p[i,0] = p0_arr[i]
    
#     # initial values at upstream reservoir
#     cn = q[1,0] - ca[0]*h[1,0] - cb - cf * q[1,0] * np.abs(q[1,0]) # negative characteristic (m3)
#     qp[0] = cn + ca[0]*h[0,0]
    
#     # interior nodes
#     for j in range(col - 1):
#         for i in range(row - 2):
#             i = i + 1 # skip first value (BCT)
#             ip1 = i + 1
#             im1 = i - 1
#             ######################## Friction Factor Calc ########################
#             f = sf.FrictionFact_jit(q[ip1,j], mu[idx[i]], sg[idx[i]], ID, rough, units=0)
#             cf = s * f/(2*(ID)*area) #(sec/m3)
#             ########################################################################
#             cn = q[ip1, j] - ca[idx[i]]*h[ip1,j] - cb - cf*q[ip1,j]*np.abs(q[ip1,j]) # negative characteristic
#             cp = q[im1, j] + ca[idx[i]]*h[im1,j] - cb - cf*q[im1,j]*np.abs(q[im1,j]) # positive characteristic
#             qp[i] = 0.5 * (cn + cp) # flow rate at future time
#             hp[i] = (cp - qp[i])/ ca[idx[i]] # head at future time
#             if i == 1: # calculations for upstream reservoir BCTs
#                 hp[0] = h[0,0] # Constant upstream reservoir head (m)
#                 qp[0] = cn + ca[idx[i]]*hp[0]
#             if i == row - 2: # calculations for downstream valve BCTs
#                 #interpolate valve 
#                 interp = t[j]
#                 if interp >= Tc:
#                     tau = 0
#                 else:
#                     I = 0
#                     while interp >= tc[I]:
#                         I = I + 1
#                     frac = (interp - tc[I-1]) / (tc[I] - tc[I-1])
#                     tau = y[I-1] + frac * (y[I] - y[I-1])
        
#                 cv = (tau * q[row-1,0] * q[row-1,0]) / (ca[idx[i]] * h[row-1,0])
#                 qp[i+1] = 0.5 * (-cv + ((cv*cv) + 4 * cp * cv)**(0.5))
#                 hp[i+1] = (cp - qp[i])/ ca[idx[i]]
#         q[:,j+1] = qp
#         h[:,j+1] = hp
#     return q, h

# %%
# lprun -s -f MethodChar01 -r MethodChar01(x,t,q0_arr,h0_arr,p0_arr,ca, cf, cb, idx, sg, d, mu, rough,s,row, col, qp, hp, hin, qin, pin,rho,area,v,Re,f)
# %timeit q, h = MethodChar01(x,t,q0_arr,h0_arr,p0_arr,ca, cf, cb, idx, sg, d, mu, rough,s,row, col, qp, hp, hin, qin, pin,rho,area,v,Re,f)

# %%
q, h = sf.MethodChar01_jit(x,t,q0_arr,h0_arr,p0_arr,ca,cf,cb,idx,sg,d,mu,rough,s,
                           row,col,qp,hp,hin,qin,pin,rho,area,v,Re,f, Tc, tc, y)

# %%
## Check Data Types (avoid pyobjects)
# main2.inspect_types()

# %% [markdown]
# ### Plot Results

# %%
PlotName = str(nel) + 'el' + '_' + str(Courant) + 'cr'
print(PlotName)
# Out:
# 800el_1.0cr

# %%
print(x.shape)
print(h.shape)
max_value = max(h[-1,:])
max_index = np.argmax(h[-1,:])
print(max_value)
print(max_index*s)
# Out:
# (801,)
# (801, 120001)
# 1948.26103973
# 10.001

# %%
# figure h
fig_h, ax = plt.subplots(figsize = (12,8))

start= 0
stop = h.shape[1]
inc = (h.shape[1]-1)/20

lbl = [None]*len(t[start:stop:inc])
for i in xrange(len(lbl)):
    lbl[i] = 'time = '+ str(t[start:stop:inc][i])
    
# ax.plot(h[:,start:stop:inc],x)
ax.plot(h[:,start:stop:inc],x[:])
ax.legend(lbl, frameon=1, framealpha = 1, loc=0)

# ax.invert_yaxis()
ax.set_xlabel('Head (m)', fontsize = 12)
ax.set_ylabel('Length (m)', fontsize = 12)
# ax.set_title(''r'Time Integration Convergence Analysis, $\alpha = 0.5 \Rightarrow$ Implicit' , fontsize = 16)
ax.grid(b = True, which = 'major')
ax.grid(b = True, which = 'major')
# ax.set_ylim(0, 2)

# fig_name = 'HeadTime.pdf'
# path = '/Users/Lampe/Documents/PB/SurgeAnalysis/Results/'
# fig_h.savefig(path + PlotName + '_' + fig_name)

# %%
fig_HeadAtWH, ax = plt.subplots(figsize = (12,8))
   
# ax.plot(h[:,start:stop:inc],x)
ax.plot(t,h[-1,:])
# ax.legend(lbl, frameon=1, framealpha = 1, loc=2)

# ax.invert_yaxis()
ax.set_ylabel('Head at Downstream Valve (m)', fontsize = 12)
ax.set_xlabel('Analysis Time (sec)', fontsize = 12)
# ax.set_title(''r'Time Integration Convergence Analysis, $\alpha = 0.5 \Rightarrow$ Implicit' , fontsize = 16)
ax.grid(b = True, which = 'major')
ax.grid(b = True, which = 'major')
# ax.set_ylim(0, 2)

fig_name = 'HeadAtWH.pdf'
path = '/Users/Lampe/Documents/PB/SurgeAnalysis/Results/'
fig_HeadAtWH.savefig(path + PlotName + '_' + fig_name)

# %%
fig_QAtWH, ax = plt.subplots(figsize = (12,8))
   

ax.plot(t,q[-1,:])
# ax.legend(lbl, frameon=1, framealpha = 1, loc=2)

# ax.invert_yaxis()
ax.set_ylabel('Flow Rate at Downstream Valve (m/sec)', fontsize = 12)
ax.set_xlabel('Analysis Time (sec)', fontsize = 12)
# ax.set_title(''r'Time Integration Convergence Analysis, $\alpha = 0.5 \Rightarrow$ Implicit' , fontsize = 16)
ax.grid(b = True, which = 'major')
ax.grid(b = True, which = 'major')
# ax.set_ylim(0, 2)

fig_name = 'FlowRateAtWH.pdf'
path = '/Users/Lampe/Documents/PB/SurgeAnalysis/Results/'
fig_QAtWH.savefig(path + PlotName + '_' + fig_name)

# %%
# figure h
fig_q, ax = plt.subplots(figsize = (12,8))

# start= 0
# stop = q.shape[1]
# inc =  (q.shape[1]-1)/20

# lbl = [None]*len(t[start:stop:inc])
for i in xrange(len(lbl)):
    lbl[i] = 'time = '+ str(t[start:stop:inc][i])
    
ax.plot(t,q[0,:])
# ax.plot(q[:,start:stop:inc],x[:])
# ax.legend(lbl, frameon=1, framealpha = 1, loc=0)

# ax.invert_yaxis()
ax.set_ylabel('Flow Rate at End of Tubing (m3/sec)', fontsize = 12)
ax.set_xlabel('Analysis Time (sec)', fontsize = 12)
# ax.set_title(''r'Time Integration Convergence Analysis, $\alpha = 0.5 \Rightarrow$ Implicit' , fontsize = 16)
ax.grid(b = True, which = 'major')
ax.grid(b = True, which = 'major')
# ax.set_ylim(0, 2)

fig_name = 'FlowRateAtEOT.pdf'
path = '/Users/Lampe/Documents/PB/SurgeAnalysis/Results/'
fig_q.savefig(path + PlotName + '_' + fig_name)
